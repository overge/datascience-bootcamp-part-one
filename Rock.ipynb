# %%
import pandas as pd

# %%
songs = pd.read_csv('data/rock.csv')

# %%
songs
# Out:
#                                        Song Clean   ARTIST CLEAN Release Year  \
# 0                                Caught Up in You    .38 Special         1982
# 1                                    Fantasy Girl    .38 Special          NaN
# 2                                 Hold On Loosely    .38 Special         1981
# 3                          Rockin' Into the Night    .38 Special         1980
# 4                               Art For Arts Sake           10cc         1975
# 5                                      Kryptonite   3 Doors Down         2000
# 6                                           Loser   3 Doors Down         2000
# 7                                   When I'm Gone   3 Doors Down         2002
# 8                                      What's Up?  4 Non Blondes         1992
# 9                                      Take On Me           a-ha         1985
# 10                          Baby, Please Don't Go          AC/DC          NaN
# ...

# %%
len(songs[songs['Release Year'] == '1981'])
# Out:
# 61

# %%
mask = songs['Release Year'] == '1981'

# %%
songs[mask]
# Out:
#                                 Song Clean  \
# 2                          Hold On Loosely
# 15                 For Those About To Rock
# 178                    Lonely Is the Night
# 182                             The Stroke
# 205                        Burnin' for You
# 479                            Heavy Metal
# 488                    Love Is Like A Rock
# 573                       I Can't Stand It
# 650                          Juke Box Hero
# 655                                 Urgent
# 656            Waiting for a Girl Like You
# 668                                 Abacab
# 676                      Man On The Corner
# 678                        No Reply At All
# 743                      The Break Up Song
# 816                             Centerfold
# 817                           Freeze-frame
# 889                         Bad Reputation
# 892                    I Love Rock 'n Roll
# 901                     A Life Of Illusion
# 943                   Don't Stop Believin'
# ...
